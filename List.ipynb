# %%
l1=[]
print(type(l1))
# Out:
# <class 'list'>

# %%
l2=[10,20,30]  #List with integer values
l3=[10.2,20.33,30.67] #List with Float Values
l4=['one','two','three']  #List with String Values
l5=['Kalyan',25,[50,100],[150,90]]  #Nested List
l6=['Babu',25.39,[1,2,3],{10,20,30},{1:'Kalyan',2:'Babu'},(4,5,6)]    #Mixed data List
print('Length of all lists')
print('List2',l2)
print('List3',l3)
print('List4',l4)
print('List5',l5)
print('List6',l6)
# Out:
# Length of all lists
# List2 [10, 20, 30]
# List3 [10.2, 20.33, 30.67]
# List4 ['one', 'two', 'three']
# List5 ['Kalyan', 25, [50, 100], [150, 90]]
# List6 ['Babu', 25.39, [1, 2, 3], {10, 20, 30}, {1: 'Kalyan', 2: 'Babu'}, (4, 5, 6)]

# %%
print(l2[0])
print(l5[1],l5[3])
print(l6[2][2])
print(l4[-1])
# Out:
# 10
# 25 [150, 90]
# 3
# three

# %%
#List Slicing
print(l6[1:3])
print(l6[2:])
print(l6[-1:])
print(l6[1::])
print(l6[::-1])
print(l6[::3])
print(l6[2::])
# Out:
# [25.39, [1, 2, 3]]
# [[1, 2, 3], {10, 20, 30}, {1: 'Kalyan', 2: 'Babu'}, (4, 5, 6)]
# [(4, 5, 6)]
# [25.39, [1, 2, 3], {10, 20, 30}, {1: 'Kalyan', 2: 'Babu'}, (4, 5, 6)]
# [(4, 5, 6), {1: 'Kalyan', 2: 'Babu'}, {10, 20, 30}, [1, 2, 3], 25.39, 'Babu']
# ['Babu', {10, 20, 30}]
# [[1, 2, 3], {10, 20, 30}, {1: 'Kalyan', 2: 'Babu'}, (4, 5, 6)]

# %%
#ADD, REMOVE, & CHANGE Items
l6.append('Welcome')
l6
# Out:
# ['Babu',
#  25.39,
#  [1, 2, 3],
#  {10, 20, 30},
#  {1: 'Kalyan', 2: 'Babu'},
#  (4, 5, 6),
#  'Welcome']

# %%
l6.insert(2,'Kalyan')
l6
# Out:
# ['Babu',
#  25.39,
#  'Kalyan',
#  [1, 2, 3],
#  {10, 20, 30},
#  {1: 'Kalyan', 2: 'Babu'},
#  (4, 5, 6),
#  'Welcome']

# %%
l6.remove({10,20,30})
l6
# Out:
# ['Babu',
#  25.39,
#  'Kalyan',
#  [1, 2, 3],
#  {1: 'Kalyan', 2: 'Babu'},
#  (4, 5, 6),
#  'Welcome']

# %%
l6.pop()
# Out:
# 'Welcome'

# %%
l6.pop(1)
# Out:
# 25.39

# %%
del l6[3]
l6
# Out:
# ['Babu', 'Kalyan', [1, 2, 3]]

# %%
l6[0]='They'
l6[1]='Call'
l6[2]='Him'
l6.append('OG')
l6
# Out:
# ['They', 'Call', 'Him', 'OG']

# %%
l5.clear()
l5
# Out:
# []

# %%
l4
# Out:
# ['one', 'two', 'three']

# %%
del l4
l4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 del l4
#       2 l4
#
# NameError: name 'l4' is not defined

# %%
l3
# Out:
# [10.2, 20.33, 30.67]

# %%
OG=l6
OG
# Out:
# ['They', 'Call', 'Him', 'OG']

# %%
id(OG),id(l6)
# Out:
# (2250505625408, 2250505625408)

# %%
l7=l6.copy()

# %%
id(l7)
# Out:
# 2250514025920

# %%
print(OG,l6,l7)
# Out:
# ['They', 'Call', 'Him', 'OG'] ['They', 'Call', 'Him', 'OG'] ['They', 'Call', 'Him', 'OG']

# %%
#Join List
list1=['one','two','three']
list2=['four','five','six']
list3=list1+list2
list3
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six']

# %%
#List Membership
'two' in list3
# Out:
# True

# %%
'seven' in list3
# Out:
# False

# %%
if 'four' in list3:
    print('four is present in list3')
else:
    print('did not in list3')
# Out:
# four is present in list3

# %%
if 'nine' in list3:
    print('four is present in list3')
else:
    print('did not in list3')
# Out:
# did not in list3

# %%
#Reverse & Sort List
print(list3)
list3.reverse()
print(list3)
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six']
# ['six', 'five', 'four', 'three', 'two', 'one']

# %%
print(list2[::-1])
# Out:
# ['six', 'five', 'four']

# %%
list4=[8,5,4,10]
print(list4)
list4.sort()
print(list4)
list4.sort(reverse=True)
print(list4)
# Out:
# [8, 5, 4, 10]
# [4, 5, 8, 10]
# [10, 8, 5, 4]

# %%
list5=[10,40,50,30,20]
print(sorted(list5))
# Out:
# [10, 20, 30, 40, 50]

# %%
print(list5)
# Out:
# [10, 40, 50, 30, 20]

# %%
#Loop Through a List
list3
# Out:
# ['six', 'five', 'four', 'three', 'two', 'one']

# %%
for i in list3:
    print(i)
# Out:
# six
# five
# four
# three
# two
# one

# %%
for i in enumerate(list3):
    print(i)
# Out:
# (0, 'six')
# (1, 'five')
# (2, 'four')
# (3, 'three')
# (4, 'two')
# (5, 'one')

# %%
#Count
list4=['one','two','one',10,20,10,'two',20,30,20,40,'three']
print(list4.count('one'))
print(list4.count(20))
# Out:
# 2
# 3

# %%
list7=[2,3,7,1,0]
print(list5)
print(list7)
# Out:
# [10, 40, 50, 30, 20]
# [2, 3, 7, 1, 0]

# %%
all(list7)
# Out:
# False

# %%
any(list7)
# Out:
# True

# %%
all(list5)
# Out:
# True
