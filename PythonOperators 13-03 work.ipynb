# %% [markdown]
# # arithmetic operator

# %%
x1, y1 = 9, 7

# %%
x1 + y1
# Out:
# 16

# %%
x1 - y1
# Out:
# 2

# %%
x1 * y1
# Out:
# 63

# %%
x1 / y1
# Out:
# 1.2857142857142858

# %%
x1 // y1
# Out:
# 1

# %%
x1 % y1  #reminder
# Out:
# 2

# %% [markdown]
# 2 * 3

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# # assignement operator

# %%
x = 7

# %%
x = x + 2
x
# Out:
# 9

# %%
x += 2
x
# Out:
# 11

# %%
x *= 2
x
# Out:
# 22

# %%
x *= 2
x
# Out:
# 44

# %%
x  * = 2
x
# Out:
#   Cell In[23], line 1
#     x  * = 2
#          ^
# SyntaxError: invalid syntax

# %%
x  *= 2
x
# Out:
# 88

# %%
x //= 2
x
# Out:
# 44

# %% [markdown]
# # unary operator

# %%
n = 7 #negattion
n
# Out:
# 7

# %%
m = -n
m
# Out:
# -7

# %%
-n
# Out:
# -7

# %% [markdown]
# # Relational operator

# %%
a = 5
b = 4

# %%
a < b
# Out:
# False

# %%
b< a
# Out:
# True

# %%
a = b

# %%
a == b
# Out:
# True

# %%
c = 10
d = 20

# %%
c == d
# Out:
# False

# %%
c = d

# %%
print(c)
print(d)
# Out:
# 20
# 20

# %%
c == d
# Out:
# True

# %%
c != d
# Out:
# False

# %%
print(c)
print(d)
# Out:
# 20
# 20

# %%
c > d
# Out:
# False

# %%
c >= d
# Out:
# True

# %%
c < d
# Out:
# False

# %%
c <= d
# Out:
# True

# %% [markdown]
# # logical table

# %%
a = 5
b = 4

# %%
a < 8 and b < 5
# Out:
# True

# %%
a < 8 or b < 5
# Out:
# True

# %%
a < 8 or b > 5
# Out:
# True

# %%
print(a)
print(b)
# Out:
# 5
# 4

# %%
a < 8 and b < 2
# Out:
# False

# %%
a>8 or b<2
# Out:
# False

# %%
x = True
x
# Out:
# True

# %%
not x
# Out:
# False

# %%
-True
# Out:
# -1

# %%
-False
# Out:
# 0

# %%
10 + 3 * 2 - 1
# Out:
# 15

# %%
10 + 3 * (2 - 1)
# Out:
# 13

# %%
print(10) 
print(10,20)  
print('python')  
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1=20 
num2=30 

add=num1+num2 

print(add)
# Out:
# 50

# %% [markdown]
# # 16th
