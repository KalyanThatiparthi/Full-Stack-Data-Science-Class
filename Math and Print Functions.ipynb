# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
x=round(math.sqrt(25))
x
# Out:
# 5

# %%
math.floor(3.9)
# Out:
# 3

# %%
math.ceil(3.9)
# Out:
# 4

# %%
pow(2,3)
# Out:
# 8

# %%
math.ceil(math.pi)
# Out:
# 4

# %%
import math as m

# %%
m.sqrt(81)
# Out:
# 9.0

# %%
from math import sqrt,pow

# %%
print(sqrt(64))
# Out:
# 8.0

# %%
print(pow(5,3))
# Out:
# 125.0

# %%
from math import *

# %%
x=min(5,10,25)
x
y=max(5,10,25)
y
# Out:
# 25

# %%
x=abs(-7.25)
x
# Out:
# 7.25

# %% [markdown]
# #Print Functions

# %%
print("Hello", "how are you?")
x = ("apple", "banana", "cherry")
print(x)
print("Hello", "how are you?", sep="--->")
# Out:
# Hello how are you?
# ('apple', 'banana', 'cherry')
# Hello--->how are you?

# %% [markdown]
# #Input Functions

# %%
print('Enter your name:')
x = input()
print('Hello, ' + x)
# Out:
# Enter your name:
#  kalyan
# Hello, kalyan

# %%
x = input()
y = input()
z = int(x) + int(y)
print(z)
# Out:
#  5
#  6
# 11

# %%
a = input('Enter user_name: ')
b = input('Enter password: ')
c = a + b
print(c)
# Out:
# Enter user_name:  kalyan
# Enter password:  12345
# kalyan12345

# %%
print("Logged in User=",a," Password=",b)
# Out:
# Logged in User= kalyan  Password= 12345

# %%
a=int(input('Enter twelve digit Aadhar Number'))
result =str(a)[8:12]
print("Your Aadhar Number:<b> **** **** ",result,"</b>")
# Out:
# Enter twelve digit Aadhar Number 456789354854
# Your Aadhar Number:<b> **** ****  4854 </b>
