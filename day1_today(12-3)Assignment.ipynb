# %% [markdown]
# # Variable declartion in python
# - variable(object) = value (datatypes)

# %%
n=102
n
# Out:
# 102

# %%
103 = n
# Out:
#   Cell In[3], line 1
#     103 = n
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
# 
1n = 10 
1n
# Out:
#   Cell In[4], line 2
#     1n = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
n1 = 10
n1
# Out:
# 10

# %%
n = 20
N
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 n = 20
# ----> 2 N
#
# NameError: name 'N' is not defined

# %%
n
# Out:
# 20

# %%
a = 35
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 a = 35
# ----> 2 A
#
# NameError: name 'A' is not defined

# %%
n@ = 8 
n@
# Out:
#   Cell In[10], line 1
#     n@ = 8
#        ^
# SyntaxError: invalid syntax

# %%
n_ = 32
n_
# Out:
# 32

# %%
n$ = 6
n$
# Out:
#   Cell In[12], line 1
#     n$ = 6
#      ^
# SyntaxError: invalid syntax

# %%
_n = 5
_n
# Out:
# 5

# %%
_
# Out:
# '{"dataframes": [], "user": "tkaly"}'

# %%
_n
# Out:
# 5

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
for = 14
for
# Out:
#   Cell In[22], line 1
#     for = 14
#         ^
# SyntaxError: invalid syntax

# %%
For = 05
For
# Out:
#   Cell In[23], line 1
#     For = 05
#           ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
if = 76
# Out:
#   Cell In[24], line 1
#     if = 76
#        ^
# SyntaxError: invalid syntax

# %%
else = 8
# Out:
#   Cell In[25], line 1
#     else = 8
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# python datatype

# %%
i = 5 
i
# Out:
# 5

# %%
type(i)
# Out:
# int

# %%
id(i)
# Out:
# 140729957655592

# %%
f = 110.45
f
# Out:
# 110.45

# %%
type(f)
# Out:
# float

# %%
gold_price = 14800.78
gold_price
# Out:
# 14800.78

# %%
type(gold_price)
# Out:
# float

# %%
6 + 5
7 - 5
8 * 5
# Out:
# 40

# %%
print(6+5)
print(7-5)
print(8*5)
# Out:
# 11
# 2
# 40

# %%
f1 = 2.4e2
f1
# Out:
# 240.0

# %%
type(f1)
# Out:
# float

# %%
f2 = 3.5e1
f2
# Out:
# 35.0

# %%
f3 = 3.2E5
f3
# Out:
# 320000.0

# %% [markdown]
# # boolean value

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True + False - False
# Out:
# 1

# %%
True * True
# Out:
# 1

# %%
False / True  #float division
# Out:
# 0.0

# %%
False // True
# Out:
# 0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
int(True)
# Out:
# 1

# %% [markdown]
# # complex

# %%
c = 1 + 2j # 10 - real part & 20 imaginary part where j = squre root of -1 
c
# Out:
# (1+2j)

# %%
type(c)
# Out:
# complex

# %%
c = 1 + 2j 
c
# Out:
# (1+2j)

# %%
c.real
# Out:
# 1.0

# %%
c.imag
# Out:
# 2.0

# %% [markdown]
# # Integer, float, complex, bool

# %%
i = 4
i
# Out:
# 4

# %%
type(i)
# Out:
# int

# %%
f = 4.5
f
# Out:
# 4.5

# %%
type(f)
# Out:
# float

# %%
b = True
b1 = False

c = b + b1
c
# Out:
# 1

# %%
type(c)
# Out:
# int

# %%
True + False
# Out:
# 1

# %%
b = False
type(b)
# Out:
# bool

# %%
c = 1+2j
c
# Out:
# (1+2j)

# %%
type(c)
# Out:
# complex

# %%
c
# Out:
# (1+2j)

# %%
c.real
# Out:
# 1.0

# %%
c.imag
# Out:
# 2.0

# %%
c
# Out:
# (1+2j)

# %%
c1 = 3 + 4j

# %%
print(c)
print(c1)
# Out:
# (1+2j)
# (3+4j)

# %%
c + c1
# Out:
# (4+6j)

# %% [markdown]
# # string

# %%
welcome to my world
# Out:
#   Cell In[74], line 1
#     welcome to my world
#             ^
# SyntaxError: invalid syntax

# %%
'welcome to my world'
# Out:
# 'welcome to my world'

# %%
"welcome to my world"
# Out:
# 'welcome to my world'

# %%
''' welcome to my world'''
# Out:
# ' welcome to my world'

# %%
'welcome to my world 
the world is in full of blind ness 
you have to choose which one correct'
# Out:
#   Cell In[78], line 1
#     'welcome to my world
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''welcome to my world 
the world is in full of blind ness 
you have to choose which one correct'''
# Out:
# 'welcome to my world \nthe world is in full of blind ness \nyou have to choose which one correct'

# %%
str = 'python'
str
# Out:
# 'python'

# %%
str1 = 'welcome'
str1
# Out:
# 'welcome'

# %%
str1[3]
# Out:
# 'c'

# %%
str1[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 str1[9]
#
# IndexError: string index out of range

# %%
str1
# Out:
# 'welcome'

# %%
str1[-5]
# Out:
# 'l'

# %%
str1
# Out:
# 'welcome'

# %%
len(str1)
# Out:
# 7

# %%
str1[6]
# Out:
# 'e'

# %%
str1
# Out:
# 'welcome'

# %%
str1[:]
# Out:
# 'welcome'

# %%
str1[1:4] #forward slicing
# Out:
# 'elc'

# %%
str1
# Out:
# 'welcome'

# %%
s2 = 'Kalyan likes programming'
s2
# Out:
# 'Kalyan likes programming'

# %%
s2 [:]
# Out:
# 'Kalyan likes programming'

# %%
len(s2)
# Out:
# 24

# %%
s2
# Out:
# 'Kalyan likes programming'

# %%
s2[0:]
# Out:
# 'Kalyan likes programming'

# %%
s2
# Out:
# 'Kalyan likes programming'

# %%
s2[:6]
# Out:
# 'Kalyan'

# %%
s2
# Out:
# 'Kalyan likes programming'

# %%
s2[:3]
# Out:
# 'Kal'

# %%
s2
# Out:
# 'Kalyan likes programming'

# %%
s2[:]
# Out:
# 'Kalyan likes programming'

# %%
s3 = 'welcomeback kalyan'
s3
# Out:
# 'welcomeback kalyan'

# %%
s3[1:5]
# Out:
# 'elco'

# %%
s3[1:8:3]
# Out:
# 'eob'

# %%
s3
# Out:
# 'welcomeback kalyan'

# %%
s3[::1]
# Out:
# 'welcomeback kalyan'

# %%
s3[::2]
# Out:
# 'wloeakkla'

# %%
s3[::3]
# Out:
# 'wcecky'

# %%
s3
# Out:
# 'welcomeback kalyan'

# %%
s3[::-1]
# Out:
# 'naylak kcabemoclew'

# %%
s3[::-2]
# Out:
# 'nya cbmce'

# %% [markdown]
# # python tye casting

# %% [markdown]
# - car()   -- car function without argument
#
# - asian_cars('tata', 'to') -- car function with 2 argument | type of arguemnt string
#
# - german_cars('audi', 'bmw', 'fereri', 'vw') -- germ car with 4 argument
#
# - today in this code i define 3 function function ens with ():

# %% [markdown]
# # we will type cast allother data type to integer

# %%
int(2.3)
# Out:
# 2

# %%
int(2.3, 3.4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 int(2.3, 3.4)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# # other datatype to float

# %%
float(20)
# Out:
# 20.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float('20')
# Out:
# 20.0

# %%
float('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 float('ten')
#
# ValueError: could not convert string to float: 'ten'

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %% [markdown]
# # all other datatypes to bool

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1+2j)
# Out:
# True

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool( )
# Out:
# False

# %%
bool(2.3)
# Out:
# True

# %%
bool('zero')
# Out:
# True

# %%
val1 = [84,54]
val1
# Out:
# [84, 54]

# %%
import sys
sys.getsizeof(val1)
# Out:
# 72
